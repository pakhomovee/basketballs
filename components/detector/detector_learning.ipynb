# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !pip install ultralytics
# !pip install rfdetr
# !pip install pytorch_lightning
# !pip install roboflow
# !pip install faster-coco-eval
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 140.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 24.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.9 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your-token")
project = rf.workspace("roboflow-jvuqo").project("basketball-player-detection-2")
version = project.version(13)
dataset = version.download("coco")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to basketball-player-detection-2-13 in coco:: 100%|██████████| 1406/1406 [00:00<00:00, 4103.26it/s]

# %%
from rfdetr import RFDETRNano

model = RFDETRNano()

model.train(dataset_dir=dataset.location, epochs=50, batch_size=8, grad_accum_steps=2)
# Out:
# [2026-03-27 10:29:14] [INFO] rf-detr - File rf-detr-nano.pth already exists with correct MD5 hash.
# [2026-03-27 10:29:14] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-27 10:29:14] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-27 10:29:15] [INFO] rf-detr - File rf-detr-nano.pth already exists with correct MD5 hash.
# [2026-03-27 10:29:16] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# ...

# %%
from rfdetr import RFDETRLarge

model = RFDETRLarge()

model.train(dataset_dir=dataset.location, epochs=50, batch_size=8, grad_accum_steps=2)
# Out:
#                      Val — Overall Metrics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           mAP            ┃  mAR   ┃         F1 sweep         ┃
# ┡━━━━━━━━┯━━━━━━━━┯━━━━━━━━╇━━━━━━━━╇━━━━━━━━┯━━━━━━━━┯━━━━━━━━┩
# │ 50:95  │   50   │   75   │  @500  │   F1   │  Prec  │ Recall │
# ├────────┼────────┼────────┼────────┼────────┼────────┼────────┤
# │ 0.6260 │ 0.9446 │ 0.7013 │ 0.6872 │ 0.9370 │ 0.9574 │ 0.9190 │
# └────────┴────────┴────────┴────────┴────────┴────────┴────────┘
#                    Val — Per-class Metrics
# ┏━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Class   ┃ AP 50:95 ┃     AR ┃     F1 ┃ Precision ┃ Recall ┃
# ┡━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━┩
# │ ball    │   0.4725 │ 0.5584 │ 0.8730 │    0.9504 │ 0.8072 │
# │ number  │   0.4626 │ 0.5383 │ 0.8535 │    0.8684 │ 0.8392 │
# │ player  │   0.7828 │ 0.8255 │ 0.9791 │    0.9814 │ 0.9768 │
# ...

# %%
# Players dataset
from roboflow import Roboflow
rf = Roboflow(api_key="your-token")
project = rf.workspace("s-workspace-9szmw").project("basketball-player-detection-2-dayfz")
version = project.version(3)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to basketball-player-detection-2-3 in coco:: 100%|██████████| 1406/1406 [00:00<00:00, 1634.81it/s]

# %%
from rfdetr import RFDETRLarge

model = RFDETRLarge()

model.train(dataset_dir=dataset.location, epochs=50, batch_size=8, grad_accum_steps=2)
# Out:
# [2026-03-27 20:46:24] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-03-27 20:46:24] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-27 20:46:24] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-27 20:46:24] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-03-27 20:46:25] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# ...

# %%
# Players dataset

from roboflow import Roboflow
rf = Roboflow(api_key="your-token")
project = rf.workspace("s-workspace-9szmw").project("basketball-player-detection-2-dayfz")
version = project.version(3)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26m.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26m.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your-token")
project = rf.workspace("s-workspace-9szmw").project("basketball-player-detection-2-aqui3")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to basketball-player-detection-2-1 in yolo26::   7%|▋         | 192/2808 [00:00<00:01, 1918.74it/s]

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26m.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26m.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=150, imgsz=640, batch=16, device='cuda')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
# Full classes dataset

from roboflow import Roboflow
rf = Roboflow(api_key="your-token")
project = rf.workspace("s-workspace-9szmw").project("basketball-player-detection-2-dayfz")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to basketball-player-detection-2-1 in yolo26:: 100%|██████████| 2807/2807 [00:00<00:00, 3043.13it/s]

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26l.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26m.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from ultralytics import YOLO
BASE_MODEL = "yolo26s.pt"

model = YOLO(BASE_MODEL)

model.train(data=dataset.location + '/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# ...

# %%
from ultralytics import YOLO

BASE_MODEL = "yolo26m.pt"
DEFAULT_EPOCHS = 50
DEFAULT_BATCH = 16
DEFAULT_IMGSZ = 640

model = YOLO(BASE_MODEL)

model.train(data="/content/drive/MyDrive/actual_dataset/data.yaml", epochs=DEFAULT_EPOCHS, imgsz=DEFAULT_IMGSZ, batch=DEFAULT_BATCH, device='cuda')
# Out:
# ...
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

BASE_MODEL = "yolo26m.pt"
DEFAULT_EPOCHS = 100
DEFAULT_BATCH = 16
DEFAULT_IMGSZ = 640

model = YOLO(BASE_MODEL)

model.train(data="/content/drive/MyDrive/actual_dataset/data.yaml", epochs=DEFAULT_EPOCHS, imgsz=DEFAULT_IMGSZ, batch=DEFAULT_BATCH, device='cuda')
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
